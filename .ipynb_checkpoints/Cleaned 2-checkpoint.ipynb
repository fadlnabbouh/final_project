# %%
# Import depndencies 
import pandas as pd 
import numpy as np

# %%
# Loading the files 
file_path = "U.S._Chronic.csv"

# %%
# Read the data file and store it in a Pandas DataFrame.
Cardiovas_df = pd.read_csv(file_path)
Cardiovas_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource  \
# 0       2019     2019           OR         Oregon      BRFSS
# 1       2019     2019           KS         Kansas      BRFSS
# 2       2019     2019           MA  Massachusetts      BRFSS
# 3       2019     2019           AZ        Arizona      BRFSS
# 4       2019     2019           HI         Hawaii      BRFSS
#
#                     Topic            DataValueType  DataValue  DataValueAlt  \
# 0  Cardiovascular Disease         Crude Prevalence       31.5          31.5
# 1  Cardiovascular Disease         Crude Prevalence        NaN           NaN
# 2  Cardiovascular Disease         Crude Prevalence        NaN           NaN
# 3  Cardiovascular Disease  Age-adjusted Prevalence        NaN           NaN
# 4  Cardiovascular Disease         Crude Prevalence        NaN           NaN
#
#    LowConfidenceLimit  ...  StratificationCategory1  \
# 0                29.9  ...                  Overall
# 1                 NaN  ...           Race/Ethnicity
# 2                 NaN  ...                   Gender
# 3                 NaN  ...           Race/Ethnicity
# 4                 NaN  ...           Race/Ethnicity
#
#              Stratification1                       GeoLocation ResponseID  \
# 0                    Overall  POINT (-120.1550313 44.56744942)        NaN
# 1  Multiracial, non-Hispanic   POINT (-98.20078123 38.3477403)        NaN
# 2                     Female  POINT (-72.08269067 42.27687047)        NaN
# 3  Multiracial, non-Hispanic  POINT (-111.7638113 34.86597028)        NaN
# 4        White, non-Hispanic  POINT (-157.8577494 21.30485044)        NaN
#
#    LocationID  TopicID QuestionID DataValueTypeID StratificationCategoryID1  \
# 0          41      CVD     CVD5_0         CRDPREV                   OVERALL
# 1          20      CVD    CVD10_1         CRDPREV                      RACE
# 2          25      CVD    CVD10_1         CRDPREV                    GENDER
# 3           4      CVD    CVD10_1      AGEADJPREV                      RACE
# 4          15      CVD    CVD10_1         CRDPREV                      RACE
#
#   StratificationID1
# 0               OVR
# 1               MRC
# 2              GENF
# 3               MRC
# 4               WHT
#
# [5 rows x 21 columns]

# %%
# Will drop the LocatioAbbr column to make the date more clean
Cardiovas_df.drop('LocationAbbr', axis=1, inplace=True)

# %%
# This Data contains alot Of Nan values 

Cardiovas_df["ResponseID"].isna().sum()
# Out:
# 375

# %%
Cardiovas_df.head()
# Out:
#    YearStart  YearEnd   LocationDesc DataSource                   Topic  \
# 0       2019     2019         Oregon      BRFSS  Cardiovascular Disease
# 1       2019     2019         Kansas      BRFSS  Cardiovascular Disease
# 2       2019     2019  Massachusetts      BRFSS  Cardiovascular Disease
# 3       2019     2019        Arizona      BRFSS  Cardiovascular Disease
# 4       2019     2019         Hawaii      BRFSS  Cardiovascular Disease
#
#              DataValueType  DataValue  DataValueAlt  LowConfidenceLimit  \
# 0         Crude Prevalence       31.5          31.5                29.9
# 1         Crude Prevalence        NaN           NaN                 NaN
# 2         Crude Prevalence        NaN           NaN                 NaN
# 3  Age-adjusted Prevalence        NaN           NaN                 NaN
# 4         Crude Prevalence        NaN           NaN                 NaN
#
#    HighConfidenceLimit StratificationCategory1            Stratification1  \
# 0                 33.0                 Overall                    Overall
# 1                  NaN          Race/Ethnicity  Multiracial, non-Hispanic
# 2                  NaN                  Gender                     Female
# 3                  NaN          Race/Ethnicity  Multiracial, non-Hispanic
# 4                  NaN          Race/Ethnicity        White, non-Hispanic
#
#                         GeoLocation  ResponseID  LocationID TopicID  \
# 0  POINT (-120.1550313 44.56744942)         NaN          41     CVD
# 1   POINT (-98.20078123 38.3477403)         NaN          20     CVD
# 2  POINT (-72.08269067 42.27687047)         NaN          25     CVD
# 3  POINT (-111.7638113 34.86597028)         NaN           4     CVD
# 4  POINT (-157.8577494 21.30485044)         NaN          15     CVD
#
#   QuestionID DataValueTypeID StratificationCategoryID1 StratificationID1
# 0     CVD5_0         CRDPREV                   OVERALL               OVR
# 1    CVD10_1         CRDPREV                      RACE               MRC
# 2    CVD10_1         CRDPREV                    GENDER              GENF
# 3    CVD10_1      AGEADJPREV                      RACE               MRC
# 4    CVD10_1         CRDPREV                      RACE               WHT

# %%
# Will drop ResponseID  because all the values are NaN
Cardiovas_df.drop("ResponseID", axis=1 ,inplace=True)

# %%
Cardiovas_df.head()
# Out:
#    YearStart  YearEnd   LocationDesc DataSource                   Topic  \
# 0       2019     2019         Oregon      BRFSS  Cardiovascular Disease
# 1       2019     2019         Kansas      BRFSS  Cardiovascular Disease
# 2       2019     2019  Massachusetts      BRFSS  Cardiovascular Disease
# 3       2019     2019        Arizona      BRFSS  Cardiovascular Disease
# 4       2019     2019         Hawaii      BRFSS  Cardiovascular Disease
#
#              DataValueType  DataValue  DataValueAlt  LowConfidenceLimit  \
# 0         Crude Prevalence       31.5          31.5                29.9
# 1         Crude Prevalence        NaN           NaN                 NaN
# 2         Crude Prevalence        NaN           NaN                 NaN
# 3  Age-adjusted Prevalence        NaN           NaN                 NaN
# 4         Crude Prevalence        NaN           NaN                 NaN
#
#    HighConfidenceLimit StratificationCategory1            Stratification1  \
# 0                 33.0                 Overall                    Overall
# 1                  NaN          Race/Ethnicity  Multiracial, non-Hispanic
# 2                  NaN                  Gender                     Female
# 3                  NaN          Race/Ethnicity  Multiracial, non-Hispanic
# 4                  NaN          Race/Ethnicity        White, non-Hispanic
#
#                         GeoLocation  LocationID TopicID QuestionID  \
# 0  POINT (-120.1550313 44.56744942)          41     CVD     CVD5_0
# 1   POINT (-98.20078123 38.3477403)          20     CVD    CVD10_1
# 2  POINT (-72.08269067 42.27687047)          25     CVD    CVD10_1
# 3  POINT (-111.7638113 34.86597028)           4     CVD    CVD10_1
# 4  POINT (-157.8577494 21.30485044)          15     CVD    CVD10_1
#
#   DataValueTypeID StratificationCategoryID1 StratificationID1
# 0         CRDPREV                   OVERALL               OVR
# 1         CRDPREV                      RACE               MRC
# 2         CRDPREV                    GENDER              GENF
# 3      AGEADJPREV                      RACE               MRC
# 4         CRDPREV                      RACE               WHT

# %%
# The size of data 
Cardiovas_df.shape
# Out:
# (375, 19)
