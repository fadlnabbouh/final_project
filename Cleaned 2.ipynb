# %%
# Import depndencies 
import pandas as pd 
import numpy as np

# %%
# Loading the files 
file_path = "U.S._Chronic.csv"

# %%
# Read the data file and store it in a Pandas DataFrame.
Cardiovas_df = pd.read_csv(file_path)
Cardiovas_df.head()
# Out:
#    id  YearStart  YearEnd LocationAbbr   LocationDesc DataSource  \
# 0   0       2019     2019           OR         Oregon      BRFSS
# 1   1       2019     2019           KS         Kansas      BRFSS
# 2   2       2019     2019           MA  Massachusetts      BRFSS
# 3   3       2019     2019           AZ        Arizona      BRFSS
# 4   4       2019     2019           HI         Hawaii      BRFSS
#
#                     Topic            DataValueType  DataValue  DataValueAlt  \
# 0  Cardiovascular Disease         Crude Prevalence       31.5          31.5
# 1  Cardiovascular Disease         Crude Prevalence        NaN           NaN
# 2  Cardiovascular Disease         Crude Prevalence        NaN           NaN
# 3  Cardiovascular Disease  Age-adjusted Prevalence        NaN           NaN
# 4  Cardiovascular Disease         Crude Prevalence        NaN           NaN
#
#    ...  StratificationCategory1            Stratification1  \
# ...

# %%
# Will drop the LocatioAbbr , DataValueAlt  column to make the date more clean
Cardiovas_df.drop('LocationAbbr', axis=1, inplace=True)
Cardiovas_df.drop('DataValueAlt', axis=1, inplace=True)

# %%
# This Data contains alot Of Nan values 

Cardiovas_df["ResponseID"].isna().sum()
# Out:
# 369

# %%
# Will drop the QuestionID column to make the date more clean
Cardiovas_df.drop('QuestionID', axis=1, inplace=True)

# %%
Cardiovas_df.head()
# Out:
#    id  YearStart  YearEnd   LocationDesc DataSource                   Topic  \
# 0   0       2019     2019         Oregon      BRFSS  Cardiovascular Disease
# 1   1       2019     2019         Kansas      BRFSS  Cardiovascular Disease
# 2   2       2019     2019  Massachusetts      BRFSS  Cardiovascular Disease
# 3   3       2019     2019        Arizona      BRFSS  Cardiovascular Disease
# 4   4       2019     2019         Hawaii      BRFSS  Cardiovascular Disease
#
#              DataValueType  DataValue  LowConfidenceLimit  \
# 0         Crude Prevalence       31.5                29.9
# 1         Crude Prevalence        NaN                 NaN
# 2         Crude Prevalence        NaN                 NaN
# 3  Age-adjusted Prevalence        NaN                 NaN
# 4         Crude Prevalence        NaN                 NaN
#
#    HighConfidenceLimit StratificationCategory1            Stratification1  \
# 0                 33.0                 Overall                    Overall
# ...

# %%
# Will drop ResponseID  because all the values are NaN
Cardiovas_df.drop("ResponseID", axis=1 ,inplace=True)

# %%
Cardiovas_df.head()
# Out:
#    id  YearStart  YearEnd   LocationDesc DataSource                   Topic  \
# 0   0       2019     2019         Oregon      BRFSS  Cardiovascular Disease
# 1   1       2019     2019         Kansas      BRFSS  Cardiovascular Disease
# 2   2       2019     2019  Massachusetts      BRFSS  Cardiovascular Disease
# 3   3       2019     2019        Arizona      BRFSS  Cardiovascular Disease
# 4   4       2019     2019         Hawaii      BRFSS  Cardiovascular Disease
#
#              DataValueType  DataValue  LowConfidenceLimit  \
# 0         Crude Prevalence       31.5                29.9
# 1         Crude Prevalence        NaN                 NaN
# 2         Crude Prevalence        NaN                 NaN
# 3  Age-adjusted Prevalence        NaN                 NaN
# 4         Crude Prevalence        NaN                 NaN
#
#    HighConfidenceLimit StratificationCategory1            Stratification1  \
# 0                 33.0                 Overall                    Overall
# ...

# %%
# The size of data 
Cardiovas_df.shape
# Out:
# (369, 18)

# %%
Cardiovas_df.to_csv(r'Resources\CleanedUsa.csv', index = False)
