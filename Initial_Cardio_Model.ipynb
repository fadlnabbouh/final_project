# %%
# mockup of a deep learning neural network model to look at the accuracy of predicting if a person has cardiovascular disease

# %%
# import dependencies
import pandas as pd
import matplotlib as plt
import sklearn as skl
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %%
# upload csv

cardio_train_df = pd.read_csv('Resources/cardio_train.csv')
cardio_train_df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# clean data, drop id

clean_df = cardio_train_df.drop(['id'], 1)
clean_df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# 0         0       1       0
# 1         0       1       1
# 2         0       0       1
# 3         0       1       1
# 4         0       0       0
# ...     ...     ...     ...
# 69995     0       1       0
# 69996     0       1       1
# 69997     1       0       1
# 69998     0       0       1
# 69999     0       1       0
#
# [70000 rows x 12 columns]

# %%
# clean data, convert age

clean_df['age'] = (clean_df['age']/365).round(1)
clean_df
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      50.4       2     168    62.0    110     80            1     1      0
# 1      55.4       1     156    85.0    140     90            3     1      0
# 2      51.7       1     165    64.0    130     70            3     1      0
# 3      48.3       2     169    82.0    150    100            1     1      0
# 4      47.9       1     156    56.0    100     60            1     1      0
# ...     ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  52.7       2     168    76.0    120     80            1     1      1
# 69996  61.9       1     158   126.0    140     90            2     2      0
# 69997  52.2       2     183   105.0    180     90            3     1      0
# 69998  61.5       1     163    72.0    135     80            1     2      0
# 69999  56.3       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# 0         0       1       0
# 1         0       1       1
# 2         0       0       1
# 3         0       1       1
# 4         0       0       0
# ...     ...     ...     ...
# 69995     0       1       0
# 69996     0       1       1
# 69997     1       0       1
# 69998     0       0       1
# 69999     0       1       0
#
# [70000 rows x 12 columns]

# %%
# feature data for X:
# age, gender, height, weight, ap_hi, ap_lo, cholesterol, gluc, smoke, alco, active
X = clean_df.drop(['cardio'], 1).values

# %%
# feature data for y:
# "does a person have a cardiovascular disease y/n"
y = clean_df['cardio']

# %%
# training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=84)

# %%
# standard scaler instance
X_scaler = StandardScaler()

# %%
# fit standard scaler
X_scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# scale features data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# neural net
input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 20
hidden_nodes_layer2 = 8
hidden_nodes_layer3 = 8
hidden_nodes_layer4 = 4
hidden_nodes_layer5 = 4

nn_model = tf.keras.models.Sequential()

# %%
# first layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=input_features, activation="relu"))

# %%
# second layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# %%
# third layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# %%
# forth layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="relu"))

# %%
# fifth layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer5, activation="relu"))

# %%
# output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# check the structure
nn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 20)                240
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 168
# _________________________________________________________________
# dense_14 (Dense)             (None, 8)                 72
# _________________________________________________________________
# dense_15 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_16 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 541
# Trainable params: 541
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# train model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5924 - accuracy: 0.6918
# Epoch 2/100
# 1641/1641 [==============================] - 4s 3ms/step - loss: 0.5556 - accuracy: 0.7278
# Epoch 3/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5505 - accuracy: 0.7306
# Epoch 4/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5477 - accuracy: 0.7309
# Epoch 5/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5459 - accuracy: 0.7317
# Epoch 6/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5449 - accuracy: 0.7322
# Epoch 7/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5440 - accuracy: 0.7325
# Epoch 8/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5439 - accuracy: 0.7319
# Epoch 9/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5428 - accuracy: 0.7334
# Epoch 10/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5423 - accuracy: 0.7330
# Epoch 11/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5424 - accuracy: 0.7334
# Epoch 12/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5418 - accuracy: 0.7336
# Epoch 13/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5417 - accuracy: 0.7341
# Epoch 14/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5413 - accuracy: 0.7345
# Epoch 15/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5412 - accuracy: 0.7336
# Epoch 16/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5409 - accuracy: 0.7347
# Epoch 17/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5406 - accuracy: 0.7344
# Epoch 18/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5406 - accuracy: 0.7330
# Epoch 19/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5405 - accuracy: 0.7341
# Epoch 20/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5402 - accuracy: 0.7344
# Epoch 21/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5404 - accuracy: 0.7341
# Epoch 22/100
# 1641/1641 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7346
# Epoch 23/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5399 - accuracy: 0.7347
# Epoch 24/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5394 - accuracy: 0.7350
# Epoch 25/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5397 - accuracy: 0.7354
# Epoch 26/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5394 - accuracy: 0.7352
# Epoch 27/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5393 - accuracy: 0.7353
# Epoch 28/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5392 - accuracy: 0.7353
# Epoch 29/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5390 - accuracy: 0.7359
# Epoch 30/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5392 - accuracy: 0.7346
# Epoch 31/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5390 - accuracy: 0.7354
# Epoch 32/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5386 - accuracy: 0.7351
# Epoch 33/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5387 - accuracy: 0.7358
# Epoch 34/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5387 - accuracy: 0.7346
# Epoch 35/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5385 - accuracy: 0.7356
# Epoch 36/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5385 - accuracy: 0.7362
# Epoch 37/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5384 - accuracy: 0.7359
# Epoch 38/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5381 - accuracy: 0.7355
# Epoch 39/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5382 - accuracy: 0.7357
# Epoch 40/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5382 - accuracy: 0.7364
# Epoch 41/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5382 - accuracy: 0.7368
# Epoch 42/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5377 - accuracy: 0.7370
# Epoch 43/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5380 - accuracy: 0.7358
# Epoch 44/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5378 - accuracy: 0.7362
# Epoch 45/100
# 1641/1641 [==============================] - 4s 3ms/step - loss: 0.5376 - accuracy: 0.7365
# Epoch 46/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5377 - accuracy: 0.7383
# Epoch 47/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5376 - accuracy: 0.7369
# Epoch 48/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5375 - accuracy: 0.7370
# Epoch 49/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5376 - accuracy: 0.7366
# Epoch 50/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5376 - accuracy: 0.7366
# Epoch 51/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5376 - accuracy: 0.7366
# Epoch 52/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5375 - accuracy: 0.7373
# Epoch 53/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5374 - accuracy: 0.7369
# Epoch 54/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5374 - accuracy: 0.7376
# Epoch 55/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5374 - accuracy: 0.7366
# Epoch 56/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5375 - accuracy: 0.7361
# Epoch 57/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5372 - accuracy: 0.7375
# Epoch 58/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5373 - accuracy: 0.7372
# Epoch 59/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5375 - accuracy: 0.7364
# Epoch 60/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5371 - accuracy: 0.7364
# Epoch 61/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5371 - accuracy: 0.7363
# Epoch 62/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5369 - accuracy: 0.7373
# Epoch 63/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5371 - accuracy: 0.7376
# Epoch 64/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5371 - accuracy: 0.7376
# Epoch 65/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5371 - accuracy: 0.7369
# Epoch 66/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5369 - accuracy: 0.7371
# Epoch 67/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5371 - accuracy: 0.7385
# Epoch 68/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5366 - accuracy: 0.7380
# Epoch 69/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5367 - accuracy: 0.7370
# Epoch 70/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5365 - accuracy: 0.7382
# Epoch 71/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5365 - accuracy: 0.7388
# Epoch 72/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5365 - accuracy: 0.7377
# Epoch 73/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5366 - accuracy: 0.7380
# Epoch 74/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5367 - accuracy: 0.7375
# Epoch 75/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5364 - accuracy: 0.7369
# Epoch 76/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5364 - accuracy: 0.7379
# Epoch 77/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5365 - accuracy: 0.7375
# Epoch 78/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5363 - accuracy: 0.7391
# Epoch 79/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5362 - accuracy: 0.7374
# Epoch 80/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5364 - accuracy: 0.7373
# Epoch 81/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5367 - accuracy: 0.7376
# Epoch 82/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5364 - accuracy: 0.7377
# Epoch 83/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5362 - accuracy: 0.7378
# Epoch 84/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5364 - accuracy: 0.7375
# Epoch 85/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5364 - accuracy: 0.7381
# Epoch 86/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5363 - accuracy: 0.7374
# Epoch 87/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5361 - accuracy: 0.7376
# Epoch 88/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5363 - accuracy: 0.7377
# Epoch 89/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5362 - accuracy: 0.7374
# Epoch 90/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5362 - accuracy: 0.7379
# Epoch 91/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5361 - accuracy: 0.7388
# Epoch 92/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5360 - accuracy: 0.7378
# Epoch 93/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5360 - accuracy: 0.7378
# Epoch 94/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5361 - accuracy: 0.7384
# Epoch 95/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5361 - accuracy: 0.7383
# Epoch 96/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5356 - accuracy: 0.7378
# Epoch 97/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5361 - accuracy: 0.7375
# Epoch 98/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5358 - accuracy: 0.7384
# Epoch 99/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5357 - accuracy: 0.7372
# Epoch 100/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5357 - accuracy: 0.7388

# %%
# plot dataframe w/ history dictionary
df_plot = pd.DataFrame(nn_model.history.history, index=range(1, len(nn_model.history.history['loss']) + 1))

# %%
# plot loss
df_plot.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# plot accuracy

df_plot.plot(y= 'accuracy')
# Out:
# <AxesSubplot:>
