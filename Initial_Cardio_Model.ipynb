# %%
# mockup of a deep learning neural network model to look at the accuracy of predicting if a person has cardiovascular disease

# %%
# import dependencies
import pandas as pd
import numpy as np
import matplotlib as plt
import sklearn as skl
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %%
# upload csv

cardio_train_df = pd.read_csv('Resources/cardio_train.csv')
cardio_train_df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# clean data, drop id

clean_df = cardio_train_df.drop(['id'], 1)
clean_df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# 0         0       1       0
# 1         0       1       1
# 2         0       0       1
# 3         0       1       1
# 4         0       0       0
# ...     ...     ...     ...
# 69995     0       1       0
# 69996     0       1       1
# 69997     1       0       1
# 69998     0       0       1
# 69999     0       1       0
#
# [70000 rows x 12 columns]

# %%
# clean data, convert age

clean_df['age'] = (clean_df['age']/365).round(1)
clean_df
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      50.4       2     168    62.0    110     80            1     1      0
# 1      55.4       1     156    85.0    140     90            3     1      0
# 2      51.7       1     165    64.0    130     70            3     1      0
# 3      48.3       2     169    82.0    150    100            1     1      0
# 4      47.9       1     156    56.0    100     60            1     1      0
# ...     ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  52.7       2     168    76.0    120     80            1     1      1
# 69996  61.9       1     158   126.0    140     90            2     2      0
# 69997  52.2       2     183   105.0    180     90            3     1      0
# 69998  61.5       1     163    72.0    135     80            1     2      0
# 69999  56.3       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# 0         0       1       0
# 1         0       1       1
# 2         0       0       1
# 3         0       1       1
# 4         0       0       0
# ...     ...     ...     ...
# 69995     0       1       0
# 69996     0       1       1
# 69997     1       0       1
# 69998     0       0       1
# 69999     0       1       0
#
# [70000 rows x 12 columns]

# %%
# feature data for X:
# age, gender, height, weight, ap_hi, ap_lo, cholesterol, gluc, smoke, alco, active
X = clean_df.drop(['cardio'], 1).values

# %%
# feature data for y:
# "does a person have a cardiovascular disease y/n"
y = clean_df['cardio']

# %%
# training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=84)

# %%
# standard scaler instance
X_scaler = StandardScaler()

# %%
# fit standard scaler
X_scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# scale features data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# neural net
input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 20
hidden_nodes_layer2 = 8
hidden_nodes_layer3 = 8
hidden_nodes_layer4 = 4
hidden_nodes_layer5 = 4

nn_model = tf.keras.models.Sequential()

# %%
# first layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=input_features, activation="relu"))

# %%
# second layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# %%
# third layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# %%
# forth layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="relu"))

# %%
# fifth layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer5, activation="relu"))

# %%
# output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# check the structure
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                240
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 168
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 541
# Trainable params: 541
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# train model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1641/1641 [==============================] - 3s 1ms/step - loss: 0.5967 - accuracy: 0.6845
# Epoch 2/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5523 - accuracy: 0.7284
# Epoch 3/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5484 - accuracy: 0.7297
# Epoch 4/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5468 - accuracy: 0.7305
# Epoch 5/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5455 - accuracy: 0.7315
# Epoch 6/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5443 - accuracy: 0.7319
# Epoch 7/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5436 - accuracy: 0.7310
# Epoch 8/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5429 - accuracy: 0.7324
# Epoch 9/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5424 - accuracy: 0.7325
# Epoch 10/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5421 - accuracy: 0.7313
# Epoch 11/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5416 - accuracy: 0.7328
# Epoch 12/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5413 - accuracy: 0.7323
# Epoch 13/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5408 - accuracy: 0.7323
# Epoch 14/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5408 - accuracy: 0.7326
# Epoch 15/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5406 - accuracy: 0.7332
# Epoch 16/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5406 - accuracy: 0.7323
# Epoch 17/100
# 1641/1641 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7327
# Epoch 18/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5397 - accuracy: 0.7341
# Epoch 19/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5395 - accuracy: 0.7342
# Epoch 20/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5397 - accuracy: 0.7341
# Epoch 21/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5392 - accuracy: 0.7350
# Epoch 22/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5393 - accuracy: 0.7343
# Epoch 23/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5387 - accuracy: 0.7338
# Epoch 24/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5390 - accuracy: 0.7344
# Epoch 25/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5388 - accuracy: 0.7355
# Epoch 26/100
# 1641/1641 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7351
# Epoch 27/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5383 - accuracy: 0.7344
# Epoch 28/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5384 - accuracy: 0.7358
# Epoch 29/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5383 - accuracy: 0.7358
# Epoch 30/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5383 - accuracy: 0.7355
# Epoch 31/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5379 - accuracy: 0.7359
# Epoch 32/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5379 - accuracy: 0.7356
# Epoch 33/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5380 - accuracy: 0.7350
# Epoch 34/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5380 - accuracy: 0.7354
# Epoch 35/100
# 1641/1641 [==============================] - 5s 3ms/step - loss: 0.5377 - accuracy: 0.7357
# Epoch 36/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5379 - accuracy: 0.7346
# Epoch 37/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5375 - accuracy: 0.7362
# Epoch 38/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5374 - accuracy: 0.7357
# Epoch 39/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5376 - accuracy: 0.7355
# Epoch 40/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5374 - accuracy: 0.7359
# Epoch 41/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5375 - accuracy: 0.7358
# Epoch 42/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5375 - accuracy: 0.7354
# Epoch 43/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5373 - accuracy: 0.7363
# Epoch 44/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5370 - accuracy: 0.7357
# Epoch 45/100
# 1641/1641 [==============================] - 5s 3ms/step - loss: 0.5371 - accuracy: 0.7364
# Epoch 46/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5371 - accuracy: 0.7365
# Epoch 47/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5369 - accuracy: 0.7364
# Epoch 48/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5370 - accuracy: 0.7362
# Epoch 49/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5368 - accuracy: 0.7364
# Epoch 50/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5366 - accuracy: 0.7360
# Epoch 51/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5370 - accuracy: 0.7363
# Epoch 52/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5369 - accuracy: 0.7362
# Epoch 53/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5365 - accuracy: 0.7370
# Epoch 54/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5367 - accuracy: 0.7353
# Epoch 55/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5367 - accuracy: 0.7361
# Epoch 56/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5365 - accuracy: 0.7360
# Epoch 57/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5368 - accuracy: 0.7368
# Epoch 58/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5365 - accuracy: 0.7363
# Epoch 59/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5367 - accuracy: 0.7372
# Epoch 60/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5366 - accuracy: 0.7364
# Epoch 61/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5364 - accuracy: 0.7365
# Epoch 62/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5364 - accuracy: 0.7382
# Epoch 63/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5360 - accuracy: 0.7369
# Epoch 64/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5363 - accuracy: 0.7368
# Epoch 65/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5362 - accuracy: 0.7368
# Epoch 66/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5361 - accuracy: 0.7362
# Epoch 67/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5362 - accuracy: 0.7368
# Epoch 68/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5358 - accuracy: 0.7371
# Epoch 69/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5361 - accuracy: 0.7376
# Epoch 70/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5357 - accuracy: 0.7366
# Epoch 71/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5358 - accuracy: 0.7367
# Epoch 72/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5357 - accuracy: 0.7373
# Epoch 73/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5358 - accuracy: 0.7368
# Epoch 74/100
# 1641/1641 [==============================] - 8s 5ms/step - loss: 0.5358 - accuracy: 0.7379
# Epoch 75/100
# 1641/1641 [==============================] - 5s 3ms/step - loss: 0.5356 - accuracy: 0.7383
# Epoch 76/100
# 1641/1641 [==============================] - 5s 3ms/step - loss: 0.5357 - accuracy: 0.7379
# Epoch 77/100
# 1641/1641 [==============================] - 5s 3ms/step - loss: 0.5354 - accuracy: 0.7372
# Epoch 78/100
# 1641/1641 [==============================] - 5s 3ms/step - loss: 0.5362 - accuracy: 0.7375
# Epoch 79/100
# 1641/1641 [==============================] - 6s 3ms/step - loss: 0.5353 - accuracy: 0.7373
# Epoch 80/100
# 1641/1641 [==============================] - 5s 3ms/step - loss: 0.5352 - accuracy: 0.7390
# Epoch 81/100
# 1641/1641 [==============================] - 6s 4ms/step - loss: 0.5354 - accuracy: 0.7380
# Epoch 82/100
# 1641/1641 [==============================] - 7s 4ms/step - loss: 0.5354 - accuracy: 0.7365
# Epoch 83/100
# 1641/1641 [==============================] - 4s 3ms/step - loss: 0.5355 - accuracy: 0.7376
# Epoch 84/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5355 - accuracy: 0.7384
# Epoch 85/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5352 - accuracy: 0.7380
# Epoch 86/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5351 - accuracy: 0.7381
# Epoch 87/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5353 - accuracy: 0.7366
# Epoch 88/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5351 - accuracy: 0.7372
# Epoch 89/100
# 1641/1641 [==============================] - 2s 1ms/step - loss: 0.5353 - accuracy: 0.7373
# Epoch 90/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5351 - accuracy: 0.7376
# Epoch 91/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5348 - accuracy: 0.7373
# Epoch 92/100
# 1641/1641 [==============================] - 4s 3ms/step - loss: 0.5351 - accuracy: 0.7379
# Epoch 93/100
# 1641/1641 [==============================] - 5s 3ms/step - loss: 0.5349 - accuracy: 0.7379
# Epoch 94/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5348 - accuracy: 0.7383
# Epoch 95/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5348 - accuracy: 0.7385
# Epoch 96/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5352 - accuracy: 0.7374
# Epoch 97/100
# 1641/1641 [==============================] - 4s 2ms/step - loss: 0.5350 - accuracy: 0.7368
# Epoch 98/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5350 - accuracy: 0.7374
# Epoch 99/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5348 - accuracy: 0.7378
# Epoch 100/100
# 1641/1641 [==============================] - 3s 2ms/step - loss: 0.5347 - accuracy: 0.7372

# %%
# plot dataframe w/ history dictionary
df_plot = pd.DataFrame(nn_model.history.history, index=range(1, len(nn_model.history.history['loss']) + 1))

# %%
# plot loss
df_plot.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# plot accuracy

df_plot.plot(y= 'accuracy')
# Out:
# <AxesSubplot:>
