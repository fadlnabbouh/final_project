# %%
# Import depndencies 
import pandas as pd 
import numpy as np

# %%
# Loading the files 
file_path = "U.S._Chronic.csv"

# %%
# Read the data file and store it in a Pandas DataFrame.
Cardiovas_df = pd.read_csv(file_path)
Cardiovas_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource  \
# 0       2019     2019           OR         Oregon      BRFSS
# 1       2019     2019           KS         Kansas      BRFSS
# 2       2019     2019           MA  Massachusetts      BRFSS
# 3       2019     2019           AZ        Arizona      BRFSS
# 4       2019     2019           HI         Hawaii      BRFSS
#
#                     Topic            DataValueType  DataValue  DataValueAlt  \
# 0  Cardiovascular Disease         Crude Prevalence       31.5          31.5
# 1  Cardiovascular Disease         Crude Prevalence        NaN           NaN
# 2  Cardiovascular Disease         Crude Prevalence        NaN           NaN
# 3  Cardiovascular Disease  Age-adjusted Prevalence        NaN           NaN
# 4  Cardiovascular Disease         Crude Prevalence        NaN           NaN
#
#    LowConfidenceLimit  ...  StratificationCategory1  \
# 0                29.9  ...                  Overall
# 1                 NaN  ...           Race/Ethnicity
# 2                 NaN  ...                   Gender
# 3                 NaN  ...           Race/Ethnicity
# 4                 NaN  ...           Race/Ethnicity
#
#              Stratification1                       GeoLocation ResponseID  \
# 0                    Overall  POINT (-120.1550313 44.56744942)        NaN
# 1  Multiracial, non-Hispanic   POINT (-98.20078123 38.3477403)        NaN
# 2                     Female  POINT (-72.08269067 42.27687047)        NaN
# 3  Multiracial, non-Hispanic  POINT (-111.7638113 34.86597028)        NaN
# 4        White, non-Hispanic  POINT (-157.8577494 21.30485044)        NaN
#
#    LocationID  TopicID QuestionID DataValueTypeID StratificationCategoryID1  \
# 0          41      CVD     CVD5_0         CRDPREV                   OVERALL
# 1          20      CVD    CVD10_1         CRDPREV                      RACE
# 2          25      CVD    CVD10_1         CRDPREV                    GENDER
# 3           4      CVD    CVD10_1      AGEADJPREV                      RACE
# 4          15      CVD    CVD10_1         CRDPREV                      RACE
#
#   StratificationID1
# 0               OVR
# 1               MRC
# 2              GENF
# 3               MRC
# 4               WHT
#
# [5 rows x 21 columns]

# %%
# Will drop the LocatioAbbr , DataValueAlt  column to make the date more clean
Cardiovas_df.drop('DataValueAlt', axis=1, inplace=True)

# %%
# This Data contains alot Of Nan values 

Cardiovas_df["ResponseID"].isna().sum()
# Out:
# 375

# %%
# Will drop the QuestionID column to make the date more clean
Cardiovas_df.drop('QuestionID', axis=1, inplace=True)
# Will drop ResponseID  because all the values are NaN
Cardiovas_df.drop("ResponseID", axis=1 ,inplace=True)

# %%
Cardiovas_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource  \
# 0       2019     2019           OR         Oregon      BRFSS
# 1       2019     2019           KS         Kansas      BRFSS
# 2       2019     2019           MA  Massachusetts      BRFSS
# 3       2019     2019           AZ        Arizona      BRFSS
# 4       2019     2019           HI         Hawaii      BRFSS
#
#                     Topic            DataValueType  DataValue  \
# 0  Cardiovascular Disease         Crude Prevalence       31.5
# 1  Cardiovascular Disease         Crude Prevalence        NaN
# 2  Cardiovascular Disease         Crude Prevalence        NaN
# 3  Cardiovascular Disease  Age-adjusted Prevalence        NaN
# 4  Cardiovascular Disease         Crude Prevalence        NaN
#
#    LowConfidenceLimit  HighConfidenceLimit StratificationCategory1  \
# 0                29.9                 33.0                 Overall
# 1                 NaN                  NaN          Race/Ethnicity
# 2                 NaN                  NaN                  Gender
# 3                 NaN                  NaN          Race/Ethnicity
# 4                 NaN                  NaN          Race/Ethnicity
#
#              Stratification1                       GeoLocation  LocationID  \
# 0                    Overall  POINT (-120.1550313 44.56744942)          41
# 1  Multiracial, non-Hispanic   POINT (-98.20078123 38.3477403)          20
# 2                     Female  POINT (-72.08269067 42.27687047)          25
# 3  Multiracial, non-Hispanic  POINT (-111.7638113 34.86597028)           4
# 4        White, non-Hispanic  POINT (-157.8577494 21.30485044)          15
#
#   TopicID DataValueTypeID StratificationCategoryID1 StratificationID1
# 0     CVD         CRDPREV                   OVERALL               OVR
# 1     CVD         CRDPREV                      RACE               MRC
# 2     CVD         CRDPREV                    GENDER              GENF
# 3     CVD      AGEADJPREV                      RACE               MRC
# 4     CVD         CRDPREV                      RACE               WHT

# %%
# Replace Nan values with zeroes to make it easier for machine learning 
Cardiovas_df['LocationDesc']=Cardiovas_df['LocationDesc'].fillna(0)
Cardiovas_df['DataSource']=Cardiovas_df['DataSource'].fillna(0)
Cardiovas_df['StratificationCategory1']=Cardiovas_df['StratificationCategory1'].fillna(0)
Cardiovas_df['Stratification1']=Cardiovas_df['Stratification1'].fillna(0)
Cardiovas_df['LocationID']=Cardiovas_df['LocationID'].fillna(0)
Cardiovas_df['TopicID']=Cardiovas_df['TopicID'].fillna(0)
Cardiovas_df['DataValueTypeID']=Cardiovas_df['DataValueTypeID'].fillna(0)
Cardiovas_df['DataValueTypeID']=Cardiovas_df['DataValueTypeID'].fillna(0)
Cardiovas_df['StratificationCategoryID1']=Cardiovas_df['StratificationCategoryID1'].fillna(0)
Cardiovas_df['StratificationID1']=Cardiovas_df['StratificationID1'].fillna(0)
Cardiovas_df['DataValue']=Cardiovas_df['DataValue'].fillna(0)
Cardiovas_df['LowConfidenceLimit']=Cardiovas_df['LowConfidenceLimit'].fillna(0)
Cardiovas_df['HighConfidenceLimit']=Cardiovas_df['HighConfidenceLimit'].fillna(0)

# %%
Cardiovas_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource  \
# 0       2019     2019           OR         Oregon      BRFSS
# 1       2019     2019           KS         Kansas      BRFSS
# 2       2019     2019           MA  Massachusetts      BRFSS
# 3       2019     2019           AZ        Arizona      BRFSS
# 4       2019     2019           HI         Hawaii      BRFSS
#
#                     Topic            DataValueType  DataValue  \
# 0  Cardiovascular Disease         Crude Prevalence       31.5
# 1  Cardiovascular Disease         Crude Prevalence        0.0
# 2  Cardiovascular Disease         Crude Prevalence        0.0
# 3  Cardiovascular Disease  Age-adjusted Prevalence        0.0
# 4  Cardiovascular Disease         Crude Prevalence        0.0
#
#    LowConfidenceLimit  HighConfidenceLimit StratificationCategory1  \
# 0                29.9                 33.0                 Overall
# 1                 0.0                  0.0          Race/Ethnicity
# 2                 0.0                  0.0                  Gender
# 3                 0.0                  0.0          Race/Ethnicity
# 4                 0.0                  0.0          Race/Ethnicity
#
#              Stratification1                       GeoLocation  LocationID  \
# 0                    Overall  POINT (-120.1550313 44.56744942)          41
# 1  Multiracial, non-Hispanic   POINT (-98.20078123 38.3477403)          20
# 2                     Female  POINT (-72.08269067 42.27687047)          25
# 3  Multiracial, non-Hispanic  POINT (-111.7638113 34.86597028)           4
# 4        White, non-Hispanic  POINT (-157.8577494 21.30485044)          15
#
#   TopicID DataValueTypeID StratificationCategoryID1 StratificationID1
# 0     CVD         CRDPREV                   OVERALL               OVR
# 1     CVD         CRDPREV                      RACE               MRC
# 2     CVD         CRDPREV                    GENDER              GENF
# 3     CVD      AGEADJPREV                      RACE               MRC
# 4     CVD         CRDPREV                      RACE               WHT

# %%
 # .str.replace to understand the structure of the column which parts will be removed  
    
Cardiovas_df['GeoLocation'].str.replace(r"([POINT])", r" \1").str.split(expand=True)
# Out:
# <ipython-input-10-9e9def42366c>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   Cardiovas_df['GeoLocation'].str.replace(r"([POINT])", r" \1").str.split(expand=True)
#      0  1  2  3  4              5             6
# 0    P  O  I  N  T  (-120.1550313  44.56744942)
# 1    P  O  I  N  T  (-98.20078123   38.3477403)
# 2    P  O  I  N  T  (-72.08269067  42.27687047)
# 3    P  O  I  N  T  (-111.7638113  34.86597028)
# 4    P  O  I  N  T  (-157.8577494  21.30485044)
# ..  .. .. .. .. ..            ...           ...
# 370  P  O  I  N  T  (-68.98503134  45.25422889)
# 371  P  O  I  N  T  (-111.7638113  34.86597028)
# 372  P  O  I  N  T  (-157.8577494  21.30485044)
# 373  P  O  I  N  T  (-92.56630005  38.63579078)
# 374  P  O  I  N  T  (-99.42677021  31.82724041)
#
# [375 rows x 7 columns]

# %%
# Removing POINT and the parentheses () from the column
Cardiovas_df['GeoLocation'] = Cardiovas_df['GeoLocation'].str.replace('[POINT]', '')
Cardiovas_df['GeoLocation'] = Cardiovas_df['GeoLocation'].str.replace('[()]', '')
# Out:
# <ipython-input-11-5992e21911e8>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   Cardiovas_df['GeoLocation'] = Cardiovas_df['GeoLocation'].str.replace('[POINT]', '')
# <ipython-input-11-5992e21911e8>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   Cardiovas_df['GeoLocation'] = Cardiovas_df['GeoLocation'].str.replace('[()]', '')

# %%
Cardiovas_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource  \
# 0       2019     2019           OR         Oregon      BRFSS
# 1       2019     2019           KS         Kansas      BRFSS
# 2       2019     2019           MA  Massachusetts      BRFSS
# 3       2019     2019           AZ        Arizona      BRFSS
# 4       2019     2019           HI         Hawaii      BRFSS
#
#                     Topic            DataValueType  DataValue  \
# 0  Cardiovascular Disease         Crude Prevalence       31.5
# 1  Cardiovascular Disease         Crude Prevalence        0.0
# 2  Cardiovascular Disease         Crude Prevalence        0.0
# 3  Cardiovascular Disease  Age-adjusted Prevalence        0.0
# 4  Cardiovascular Disease         Crude Prevalence        0.0
#
#    LowConfidenceLimit  HighConfidenceLimit StratificationCategory1  \
# 0                29.9                 33.0                 Overall
# 1                 0.0                  0.0          Race/Ethnicity
# 2                 0.0                  0.0                  Gender
# 3                 0.0                  0.0          Race/Ethnicity
# 4                 0.0                  0.0          Race/Ethnicity
#
#              Stratification1                GeoLocation  LocationID TopicID  \
# 0                    Overall   -120.1550313 44.56744942          41     CVD
# 1  Multiracial, non-Hispanic    -98.20078123 38.3477403          20     CVD
# 2                     Female   -72.08269067 42.27687047          25     CVD
# 3  Multiracial, non-Hispanic   -111.7638113 34.86597028           4     CVD
# 4        White, non-Hispanic   -157.8577494 21.30485044          15     CVD
#
#   DataValueTypeID StratificationCategoryID1 StratificationID1
# 0         CRDPREV                   OVERALL               OVR
# 1         CRDPREV                      RACE               MRC
# 2         CRDPREV                    GENDER              GENF
# 3      AGEADJPREV                      RACE               MRC
# 4         CRDPREV                      RACE               WHT

# %%
Cardiovas_df.dtypes
# Out:
# YearStart                      int64
# YearEnd                        int64
# LocationAbbr                  object
# LocationDesc                  object
# DataSource                    object
# Topic                         object
# DataValueType                 object
# DataValue                    float64
# LowConfidenceLimit           float64
# HighConfidenceLimit          float64
# StratificationCategory1       object
# Stratification1               object
# GeoLocation                   object
# LocationID                     int64
# TopicID                       object
# DataValueTypeID               object
# StratificationCategoryID1     object
# StratificationID1             object
# dtype: object

# %%
Cardiovas_df['GeoLocation']
# Out:
# 0       -120.1550313 44.56744942
# 1        -98.20078123 38.3477403
# 2       -72.08269067 42.27687047
# 3       -111.7638113 34.86597028
# 4       -157.8577494 21.30485044
#                  ...
# 370     -68.98503134 45.25422889
# 371     -111.7638113 34.86597028
# 372     -157.8577494 21.30485044
# 373     -92.56630005 38.63579078
# 374     -99.42677021 31.82724041
# Name: GeoLocation, Length: 375, dtype: object

# %%
Cardiovas_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource  \
# 0       2019     2019           OR         Oregon      BRFSS
# 1       2019     2019           KS         Kansas      BRFSS
# 2       2019     2019           MA  Massachusetts      BRFSS
# 3       2019     2019           AZ        Arizona      BRFSS
# 4       2019     2019           HI         Hawaii      BRFSS
#
#                     Topic            DataValueType  DataValue  \
# 0  Cardiovascular Disease         Crude Prevalence       31.5
# 1  Cardiovascular Disease         Crude Prevalence        0.0
# 2  Cardiovascular Disease         Crude Prevalence        0.0
# 3  Cardiovascular Disease  Age-adjusted Prevalence        0.0
# 4  Cardiovascular Disease         Crude Prevalence        0.0
#
#    LowConfidenceLimit  HighConfidenceLimit StratificationCategory1  \
# 0                29.9                 33.0                 Overall
# 1                 0.0                  0.0          Race/Ethnicity
# 2                 0.0                  0.0                  Gender
# 3                 0.0                  0.0          Race/Ethnicity
# 4                 0.0                  0.0          Race/Ethnicity
#
#              Stratification1                GeoLocation  LocationID TopicID  \
# 0                    Overall   -120.1550313 44.56744942          41     CVD
# 1  Multiracial, non-Hispanic    -98.20078123 38.3477403          20     CVD
# 2                     Female   -72.08269067 42.27687047          25     CVD
# 3  Multiracial, non-Hispanic   -111.7638113 34.86597028           4     CVD
# 4        White, non-Hispanic   -157.8577494 21.30485044          15     CVD
#
#   DataValueTypeID StratificationCategoryID1 StratificationID1
# 0         CRDPREV                   OVERALL               OVR
# 1         CRDPREV                      RACE               MRC
# 2         CRDPREV                    GENDER              GENF
# 3      AGEADJPREV                      RACE               MRC
# 4         CRDPREV                      RACE               WHT

# %%
Cardiovas_df.to_csv(r'Resources\CleanedUsa.csv', index = False)
